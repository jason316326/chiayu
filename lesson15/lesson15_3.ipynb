# %%
#假設有一家分店30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([7577, 4491, 5871, 4016, 1328, 4529, 4168, 2223, 6307, 9621,  670,
#        4949, 4889, 7199, 3669, 7839, 8152,  264, 9923, 4024, 2315, 3603,
#        5723, 5243, 6359, 8465, 1991, 7094, 9243, 7332], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  7577,  12068,  17939,  21955,  23283,  27812,  31980,  34203,
#         40510,  50131,  50801,  55750,  60639,  67838,  71507,  79346,
#         87498,  87762,  97685, 101709, 104024, 107627, 113350, 118593,
#        124952, 133417, 135408, 142502, 151745, 159077])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
