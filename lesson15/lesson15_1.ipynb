# %%
import numpy as np
#陣列運算
a = np.array([1, 3, 5, 7, 9])
a *= 10
a
# Out:
# array([10, 30, 50, 70, 90])

# %%
a = np.array([1, 3, 5, 7, 9])
b = np.array([2, 4 , 6, 8, 10])

#陣列運算
a + b
# Out:
# array([ 3,  7, 11, 15, 19])

# %%
#2維ndarray
arr = np.array([[1, 3, 5],[2, 4, 6]])
arr.ndim #維度
arr.shape #形狀
arr.size #元素數量
arr.dtype #型別
# Out:
# dtype('int64')

# %%
np.random.rand()
np.random.rand(30, 4)
# Out:
# array([[0.11385782, 0.29563183, 0.23656102, 0.75013088],
#        [0.52664971, 0.88917103, 0.78762927, 0.75831196],
#        [0.45514941, 0.53995621, 0.62270508, 0.90739117],
#        [0.28188614, 0.62612762, 0.40282718, 0.8662164 ],
#        [0.96786902, 0.39087997, 0.52444018, 0.77008053],
#        [0.73188221, 0.5717787 , 0.37392427, 0.45925055],
#        [0.44167389, 0.52403188, 0.87782976, 0.39266575],
#        [0.17430481, 0.4040368 , 0.70179552, 0.78795063],
#        [0.44713116, 0.75392558, 0.07018642, 0.22457694],
#        [0.94071183, 0.36254696, 0.88747696, 0.29932174],
#        [0.90127634, 0.01042403, 0.92944652, 0.33561499],
#        [0.59178173, 0.84860166, 0.14047238, 0.47666977],
#        [0.45510512, 0.83617732, 0.02022105, 0.64218654],
#        [0.73895267, 0.51659195, 0.74965107, 0.7328389 ],
#        [0.22827986, 0.39570506, 0.77536397, 0.65071914],
#        [0.66586262, 0.86891852, 0.54356348, 0.45762758],
#        [0.40456848, 0.74910744, 0.03882401, 0.71751529],
#        [0.55494139, 0.83681052, 0.91276917, 0.02052575],
#        [0.90773917, 0.92814808, 0.31825444, 0.66026431],
#        [0.50253102, 0.73654756, 0.2725253 , 0.31588718],
#        [0.75384228, 0.71884847, 0.7906352 , 0.70215716],
#        [0.94708823, 0.16871875, 0.33912327, 0.69866779],
#        [0.73697976, 0.31626371, 0.97399462, 0.57322793],
#        [0.15774724, 0.35241527, 0.22712724, 0.24742139],
#        [0.08499293, 0.3388861 , 0.63860055, 0.96083237],
#        [0.72325917, 0.18943222, 0.03354157, 0.94976955],
#        [0.24979875, 0.36618959, 0.06191322, 0.25172242],
#        [0.06992163, 0.53589843, 0.70420471, 0.750971  ],
#        [0.40800034, 0.44399014, 0.29557718, 0.18702649],
#        [0.10746913, 0.59575041, 0.02386644, 0.11006091]])

# %%
scores = np.random.randint(50, 101,size=(50,5))
scores
# Out:
# array([[ 84,  65,  61,  97,  65],
#        [ 61,  98,  79,  91,  67],
#        [ 60,  92,  53,  91,  67],
#        [ 52,  63,  84,  60,  98],
#        [ 50,  94,  95,  66,  64],
#        [ 99,  56,  56,  94,  56],
#        [ 73,  95,  95,  87, 100],
#        [ 88,  87,  80,  58,  56],
#        [ 79,  98,  99,  56,  74],
#        [ 87,  81,  81,  79,  87],
#        [ 76,  53,  99,  72,  74],
#        [ 92,  60,  55,  71,  85],
#        [ 57,  91,  89,  76,  70],
#        [ 86,  68,  52,  79,  50],
#        [ 61,  78,  61,  79,  81],
#        [ 73,  77,  94,  62,  51],
#        [ 67,  94,  66, 100,  79],
#        [ 67,  60,  92,  62,  61],
#        [ 52,  59,  54,  81,  56],
#        [ 54,  64,  68,  92,  98],
#        [ 67,  57,  58,  57,  77],
#        [ 54,  62,  96,  91,  91],
#        [ 89,  99,  70,  73,  72],
#        [ 50,  52,  80,  94,  93],
#        [ 57,  99,  99,  89,  81],
#        [ 65,  98,  73,  58,  64],
#        [ 70,  95,  82,  69,  56],
#        [ 80,  65,  53,  50,  91],
#        [ 70,  74,  89,  82,  97],
#        [ 89,  68,  79,  86,  82],
#        [ 60,  53,  51,  65,  65],
#        [ 62,  71,  66,  93,  78],
#        [ 88,  72,  60,  50,  86],
#        [ 61,  56,  94,  60,  79],
#        [ 55,  82,  74,  74,  67],
#        [ 65,  60,  86,  81,  58],
#        [ 86,  97,  79,  67,  78],
#        [ 53, 100,  72,  55,  86],
#        [ 52,  79,  71,  98,  90],
#        [ 80,  98,  72,  57,  74],
#        [ 58,  82,  81,  96,  71],
#        [ 66,  93,  72,  72,  88],
#        [100,  99,  98,  85,  65],
#        [ 98,  90,  69,  96,  90],
#        [ 75,  69,  51,  84,  62],
#        [ 99,  93,  72,  93,  52],
#        [ 66,  77,  56,  65,  93],
#        [ 60,  52,  70,  51,  83],
#        [ 81,  68,  78,  55,  73],
#        [ 87,  66,  52,  67,  56]], dtype=int32)
